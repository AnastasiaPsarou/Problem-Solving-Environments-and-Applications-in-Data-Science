# %%
import pandas as pd
import os
import glob
from pathlib import Path  
import matplotlib.pyplot as plt
low_memory = False
  
# χρησιμοποιούμε το glob για να διαβάσουμε όλα τα csv αρχεία
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
  

# παίρνουμε τα ονόματα από το columns
df = pd.read_csv('LDAP1.csv')[0:1]
attacks = pd.DataFrame([], columns=df.columns)

# διατρέχουμε όλα τα csv αρχεία
for f in csv_files:
      
    df = pd.read_csv(f)[0:20000]
      
    print('Location:', f)
    print('File Name:', f.split("\\")[-1])
    print('Ddos Attack Name:', f.split("\\")[-1][:-5])
    attack_name = f.split("\\")[-1][:-5]
    attack_name = attack_name.replace('_', ' ')
    # print the content
    print('Content:')
    display(df.head())
   
    display(df.groupby(' Label').count())
    # κρατάμε όλα τα attacks για την δημιουργία του ratings.csv
    attacks = attacks.append(df, ignore_index = True)
    print("\n\n")
# Out:
# C:\Users\chris\anaconda4\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\chris\anaconda4\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\chris\anaconda4\lib\site-packages\numpy\.libs\libopenblas.xwydx2ikjw2nmtwsfyngfuwkqu3lytcz.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# Location: C:\Users\chris\Desktop\9ο ΕΞΑΜΗΝΟ\ΠΕΡΙΒΑΛΛΟΝΤΑ ΕΠΙΛΥΣΗΣ ΠΡΟΒΛΗΜΑΤΩΝ ΓΙΑ ΕΦΑΡΜΟΓΕΣ ΣΤΗΝ ΕΠΙΣΤΗΜΗ ΔΕΔΟΜΕΝΩΝ\Project 6\Project 6 - Team F\LDAP1.csv
# File Name: LDAP1.csv
# Ddos Attack Name: LDAP
# Content:
# C:\Users\chris\AppData\Local\Temp\ipykernel_2592\774802277.py:14: DtypeWarning: Columns (72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('LDAP1.csv')[0:1]
# ...

# %%
attacks.head()
# Out:
#    Source Port  Destination Port  Protocol  Flow Duration  Total Fwd Packets  \
# 0          870              2908        17              1                  2
# 1          871             53796        17             48                  2
# 2          648             40660        17              1                  2
# 3          872             54308        17              1                  2
# 4          873             40653        17              1                  2
#
#    Total Backward Packets  Total Length of Fwd Packets  \
# 0                       0                        422.0
# 1                       0                        530.0
# 2                       0                        458.0
# 3                       0                        458.0
# 4                       0                        458.0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                           0.0                   211.0
# ...

# %%
attacks.shape
# Out:
# (140000, 75)

# %%
attacks.to_csv('attacks.csv', index=False)
